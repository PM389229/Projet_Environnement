# %%
import pandas as pd
import numpy as np
data=pd.read_csv('/home/pm3829/iadev-python/ProjetEnvironnement/Energy data 1990 - 2020.csv')
data.head(5)
# Out:
#    country  Year       Region  CO2 emissions from fuel combustion (MtCO2)  \
# 0  Algeria  1990  Arab States                                   52.981921
# 1  Algeria  1991  Arab States                                   57.149971
# 2  Algeria  1992  Arab States                                   57.262430
# 3  Algeria  1993  Arab States                                   59.198702
# 4  Algeria  1994  Arab States                                   56.347927
#
#    Average CO2 emission factor (tCO2/toe)  \
# 0                                2.387855
# 1                                2.435026
# 2                                2.383517
# 3                                2.455335
# 4                                2.424649
#
#    CO2 intensity at constant purchasing power parities (kCO2/$15p)  \
# 0                                           0.228889
# 1                                           0.249895
# 2                                           0.245959
# ...

# %%
# cheking data types
data.dtypes
# Out:
# country                                                                      object
# Year                                                                          int64
# Region                                                                       object
# CO2 emissions from fuel combustion (MtCO2)                                  float64
# Average CO2 emission factor (tCO2/toe)                                      float64
# CO2 intensity at constant purchasing power parities (kCO2/$15p)             float64
# Total energy production (Mtoe)                                              float64
# Total energy consumption (Mtoe)                                             float64
# Share of renewables in electricity production (%)                           float64
# Share of electricity in total final energy consumption (%)                  float64
# Oil products domestic consumption (Mt)                                      float64
# ...

# %%
station = pd.read_csv('/home/pm3829/iadev-python/ProjetEnvironnement/Energy data 1990 - 2020.csv')
station.head(5)
# Out:
#    country  Year       Region  CO2 emissions from fuel combustion (MtCO2)  \
# 0  Algeria  1990  Arab States                                   52.981921
# 1  Algeria  1991  Arab States                                   57.149971
# 2  Algeria  1992  Arab States                                   57.262430
# 3  Algeria  1993  Arab States                                   59.198702
# 4  Algeria  1994  Arab States                                   56.347927
#
#    Average CO2 emission factor (tCO2/toe)  \
# 0                                2.387855
# 1                                2.435026
# 2                                2.383517
# 3                                2.455335
# 4                                2.424649
#
#    CO2 intensity at constant purchasing power parities (kCO2/$15p)  \
# 0                                           0.228889
# 1                                           0.249895
# 2                                           0.245959
# ...

# %%
sub_item = item[["country","Year"]]
sub_item
# Out:
#         country  Year
# 0       Algeria  1990
# 1       Algeria  1991
# 2       Algeria  1992
# 3       Algeria  1993
# 4       Algeria  1994
# ...         ...   ...
# 1359  Venezuela  2016
# 1360  Venezuela  2017
# 1361  Venezuela  2018
# 1362  Venezuela  2019
# 1363  Venezuela  2020
#
# [1364 rows x 2 columns]

# %%
#On replace les NA par des 0 , les valeurs non numeriques par N.A pour que ce soit plus facile a traiter
data['Natural gas production (bcm)'] = pd.to_numeric(data['Natural gas production (bcm)'], errors='coerce').fillna(0)
data['Coal and lignite domestic consumption (Mt)'] = pd.to_numeric(data['Coal and lignite domestic consumption (Mt)'], errors='coerce').fillna(0)
data['Share of wind and solar in electricity production (%)'] = pd.to_numeric(data['Share of wind and solar in electricity production (%)'], errors='coerce').fillna(0)
data['Coal and lignite production (Mt)'] = pd.to_numeric(data['Coal and lignite production (Mt)'], errors='coerce').fillna(0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1364 entries, 0 to 1363
# Data columns (total 21 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   country                                                                   1364 non-null   object
#  1   Year                                                                      1364 non-null   int64
#  2   Region                                                                    1364 non-null   object
#  3   CO2 emissions from fuel combustion (MtCO2)                                1364 non-null   float64
#  4   Average CO2 emission factor (tCO2/toe)                                    1364 non-null   float64
#  5   CO2 intensity at constant purchasing power parities (kCO2/$15p)           1364 non-null   float64
# ...

# %%
data.describe()
# Out:
#               Year  CO2 emissions from fuel combustion (MtCO2)  \
# count  1364.000000                                 1364.000000
# mean   2005.000000                                  550.375178
# std       8.947552                                 1213.057599
# min    1990.000000                                    7.597759
# 25%    1997.000000                                   99.947198
# 50%    2005.000000                                  221.036281
# 75%    2013.000000                                  423.833152
# max    2020.000000                                 9716.772478
#
#        Average CO2 emission factor (tCO2/toe)  \
# count                             1364.000000
# mean                                 2.238542
# std                                  0.560594
# min                                  0.412331
# 25%                                  2.021666
# 50%                                  2.339406
# 75%                                  2.521811
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 3, figsize=(20,5), gridspec_kw={'width_ratios': [1, 1, 1]})
fig.subplots_adjust(wspace=0.4)

axes[0].set_title('CO2 emissions from fuel combustion (MtCO2) distribution')
sns.boxplot(data=data, y='CO2 emissions from fuel combustion (MtCO2)', ax=axes[0]).set_ylabel('')

sns.histplot(data=data, x='CO2 emissions from fuel combustion (MtCO2)', ax=axes[1]).set_xlabel('')

grouped_data = data.groupby('country')['CO2 emissions from fuel combustion (MtCO2)'].mean().reset_index()
sorted_data = grouped_data.nlargest(10, 'CO2 emissions from fuel combustion (MtCO2)').sort_values('CO2 emissions from fuel combustion (MtCO2)', ascending=False)

sns.barplot(data=sorted_data, x='CO2 emissions from fuel combustion (MtCO2)', y='country', ax=axes[2], errorbar=None, order=sorted_data['country']).set_ylabel('')
axes[1].set_ylabel("")
axes[2].set_xlabel("")

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=data, y='CO2 emissions from fuel combustion (MtCO2)', x = 'Year', hue = 'Region', estimator = 'mean', markers = False, errorbar=None)\
.set_title('CO2 emissions from fuel combustion (MtCO2)')
plt.xlabel("")
plt.ylabel("")
plt.show()

#On affiche ici les emissions de CO2 par regions du globe

# %%
# plotting data
plt.figure(figsize=(10, 6))
sns.lineplot(data=data, y='Share of renewables in electricity production (%)', x = 'Year', hue = 'Region', estimator = 'mean', markers = False, errorbar=None)\
.set_title('Share of renewables in electricity production (%)')
plt.xlabel("")
plt.ylabel("")
plt.ylim(0, 80)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=data, y='Share of wind and solar in electricity production (%)', x = 'Year', hue = 'Region', estimator = 'mean', markers = False, errorbar=None)\
.set_title('Share of wind and solar in electricity production (%)')
plt.xlabel("")
plt.ylabel("")
plt.ylim(0, 18)
plt.show()

# %%
# Liste des pays qu'on veutgarder
selected_countries = ['France', 'Australia', 'China', 'Germany', 'India', 'Nigeria', 'United Arab Emirates', 'United States']

# Filtrer les données 
filtered_data = data[data['country'].isin(selected_countries)]

# Tracé du graphique
plt.figure(figsize=(10, 6))
sns.lineplot(data=filtered_data, y='Share of wind and solar in electricity production (%)', x='Year', hue='country', estimator='mean', markers=False, errorbar=None)
plt.title('Share of wind and solar in electricity production (%)')
plt.xlabel("")
plt.ylabel("")
plt.ylim(0, 18)
plt.show()

# %%
# Liste des pays qu'on veutgarder
selected_countries = ['France', 'Australia', 'China', 'Germany', 'India', 'Nigeria', 'United Arab Emirates', 'United States']

# Filtrer les données 
filtered_data = data[data['country'].isin(selected_countries)]

plt.figure(figsize=(10, 6))
sns.lineplot(data=filtered_data, y='Coal and lignite production (Mt)', x = 'Year', hue = 'country', estimator = 'mean', markers = False, errorbar=None)\
.set_title('Coal and lignite production (Mt)')
plt.xlabel("")
plt.ylabel("")
plt.ylim(0, 600)
plt.show()
